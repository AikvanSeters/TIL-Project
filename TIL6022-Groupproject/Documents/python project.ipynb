# %% [markdown]
# # Project Group -
#
# Members & Student numbers:
# - Aik van Seters - 4939484
# - Laura Drechsel - 4706080
# - Dion Mol       - 4943694
# - Martijn Koning - 5185904

# %% [markdown]
# # Research Objective & SMART Criteria
#
# How did COVID-19 affect travel reasons within the different provinces in The Netherlands per month?
#
#
# **SMART criteria**
#
# **Specific** - This question will focus on how covid-19 infections affected the travel reasons within the Netherlands. The purpose is to find out if this indeed happened, and if so, how much and what categories faced the largest shift?
#
# **Measurable** - Outcomes of the dataset analysis will focus on (1) the different travel reasons, (2) the differences per province, additional: (3) the different age categories within the Netherlands, (4) the changed distance (for instance, someone is maybe more likely to travel more/less distance for a specific occupation during this period).
#
# **Achievable** - Different datasets will be used, gathered over the past years by different data collecting institutions (RIVM data on covid cases, CBS travel reasons).
#
# **Relevant** - Relevance because it is useful to gain insights in the shift in travel reasons within The Netherlands due to the corona pandemic.
#
# **Time-Bound** - This research question focuses on the time period 2018 (the period before corona) until and including the year 2021. The year 2022 is left out of the analysis since data is not gathered of this entire year yet.

# %% [markdown]
# # Contribution Statement
#
# *Be specific. Some of the tasks can be coding (expect everyone to do this), background research, conceptualisation, visualisation, data analysis, data modelling*

# %% [markdown]
# We will fill this in during the next lecture/ when a clear task division has been established within the group.
#
# **Author 1**:
#
# **Author 2**:
#
# **Author 3**:
#
# **Author 4**:

# %% [markdown]
# # Data Used

# %% [markdown]
# **Data file 1** - source 1: https://data.rivm.nl/covid-19/ We will use this source to analyze the number of cases per municipality/province. Hence, once this data is sorted and analyzed, we will try to find any correlations with the data analyzed in file 2.
#
# **Data file 2** - source 2: CBS travel reasons data file https://opendata.cbs.nl/statline/portal.html?_la=en&_catalog=CBS&tableId=85055ENG&_theme=1159 The data from this file contains insights within the distance traveled, distance per day, occupation/reason for traveling, and age category.
#
# When using those 2 data files, we will try to discover if there are any correlations between the phase before corona and during corona in terms of shift in occupation, relative per age category.

# %% [markdown]
# # Data Pipeline

# %% [markdown]
# **1. Sources**: how are they categorized, what does the data consist of?
#
# **2. Data processing**: (filtering, grouping, augmentation, aggregation) steps - how is the data we have converted to the data we need?
#
# **3. Destination**: data used for making the graphs - specify variables and data used to compare in graphs. Why is the data now able to be compared?

# %% [markdown]
# # Hypothesis statements

# %% [markdown]
# Determine a hypothesis which will be tested against the data visualized in the graphs.
#
# **Potential hypothesis statement:**
#
# **Statement 1** - Do hospitalization rates rise after special events? (Test: carnival 2020, Christmas 2020)
#
# **Statement 2** - Do travel purposes change relative to the number of covid hospitalizations?
#
# **Sub questions arising from statement 2:**
#
#     • Do certain regions face a large changes in travel purposes?
#     • If yes, Which regions do?
#     • What travel purposes change the most?
#
# **Statement 3** - The average travel time for (the most changes ones) purposes has increased during the first lockdown (2020).
#
# **Statement 4** - The average travel distance for (the most changes ones) purposes has increased during the first lockdown (2020).

# %% [markdown]
# # Conditions

# %% [markdown]
# **1. Determine regions**: Graphs explained – The provinces in the Netherlands are divided in 4 main regions: Noord, Oost, West, Zuid for visualization purposes.
#
# **2. Determine the number of travel purposes used**: The number of travel purposes to be compared is dependent on the visualization of the graphs: All number of travel purposes, however, we can make it an optional graph (selecting and fading out) in which we can use all the different travel purposes.

# %% [markdown]
# ![regio_deals_3etranche_bg_feb2020_cn3.jpg](attachment:regio_deals_3etranche_bg_feb2020_cn3.jpg)

# %% [markdown]
# # Graphs & Variables

# %% [markdown]
# The following contains an outline of the graphs that will be used in order to answer our central research question (CRQ) and hypothesis stated earlier:
#
# **Graph 1: (graph per region):** the number of hospitalizations per region.
# - This is used to mark down peaks and compare if there are relations between big gatherings/ restrictions being implemented.
#
# **Graph 2: (graph per region):**
# Explaining the change in travel distance per month per travel purpose (line chart)
#
# **Graph 3: (graph per region):**
# -	Explaining the change in average travel time per month per travel purpose.
#
# **Additional 3rd graph:**
# -	Zoom-in on the region (Noord, West, Oost, Zuid) with the most corona cases and go into a more in-depth analysis in terms of travel time and travel distance.
#
#
#
# 2 scenarios for the graphs to explain the different times (before and during corona):
# -	2 individual graphs, showing the situation before and during corona
# -	1 slider graph, highlighting the period where Covid started.

# %% [markdown]
# # Graph 1: The Number of Hospitalizations per Region
