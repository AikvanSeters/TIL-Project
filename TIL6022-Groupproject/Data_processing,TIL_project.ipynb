# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#Data_Sets
    #Read Data_sets
file_path1 = 'Data/COVID-19_ziekenhuisopnames_1of2.csv'
covid_temp1 = pd.read_csv(file_path1, delimiter = ';',  parse_dates=['Date_of_statistics'], index_col = 'Date_of_statistics')

file_path2 = 'Data/COVID-19_ziekenhuisopnames_2of2.csv'
covid_temp2 = pd.read_csv(file_path2, delimiter = ';',  parse_dates=['Date_of_statistics'], index_col = 'Date_of_statistics')

    #Merge both Data_sets
covid = pd.merge(covid_temp1, covid_temp2, how = 'outer')
covid
covid.Hospital_admission.resample('M' ,kind='period').sum()
#for i in covid['Date_of_statistics']:
 #   print(i.month)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-9d98b61100c0> in <module>
#      10 covid = pd.merge(covid_temp1, covid_temp2, how = 'outer')
#      11 covid
# ---> 12 covid.Hospital_admission.resample('M' ,kind='period').sum()
#      13 #for i in covid['Date_of_statistics']:
#      14  #   print(i.month)
#
# ~\Anaconda3\envs\ox\lib\site-packages\pandas\core\series.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    5316             level=level,
#    5317             origin=origin,
# -> 5318             offset=offset,
#    5319         )
#    5320
#
# ~\Anaconda3\envs\ox\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8137             level=level,
#    8138             origin=origin,
# ...

# %%
covid_province = covid.groupby(['Date_of_statistics', 'Security_region_name']).sum()
covid_province.reset_index(inplace=True)
#covid_province['Datetime'] = pd.to_datetime(covid_province['Date_of_publication'])
fig = px.scatter(covid_province, x = 'Date_of_statistics',  y = 'Hospital_admission', color = 'Security_region_name')
fig.update_yaxes(range = [0, 100])
# Out:
# <div>                            <div id="6826e3ea-2a8a-4e56-8e84-78bc9f1120a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6826e3ea-2a8a-4e56-8e84-78bc9f1120a8")) {                    Plotly.newPlot(                        "6826e3ea-2a8a-4e56-8e84-78bc9f1120a8",                        [{"hovertemplate":"Security_region_name=Amsterdam-Amstelland<br>Date_of_statistics=%{x}<br>Hospital_admission=%{y}<extra></extra>","legendgroup":"Amsterdam-Amstelland","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Amsterdam-Amstelland","showlegend":true,"x":["1-1-2021","1-1-2022","1-10-2020","1-10-2021","1-10-2022","1-11-2020","1-11-2021","1-12-2020","1-12-2021","1-2-2021","1-2-2022","1-3-2020","1-3-2021","1-3-2022","1-4-2020","1-4-2021",
# ...

# %%
# Out:
# 353400
