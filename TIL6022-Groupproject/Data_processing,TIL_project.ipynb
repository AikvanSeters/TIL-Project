# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#Data_Sets
#Read Data_sets
file_path1 = 'Data/COVID-19_ziekenhuisopnames_1of2.csv'
covid_temp1 = pd.read_csv(file_path1, delimiter = ';',  parse_dates=['Date_of_statistics'], index_col = 'Date_of_statistics')

file_path2 = 'Data/COVID-19_ziekenhuisopnames_2of2.csv'
covid_temp2 = pd.read_csv(file_path2, delimiter = ';',  parse_dates=['Date_of_statistics'], index_col = 'Date_of_statistics')

    #Merge both Data_sets
covid = pd.merge(covid_temp1, covid_temp2, how = 'outer')
covid
# covid.Hospital_admission.resample('M' ,kind='period').sum()
#for i in covid['Date_of_statistics']:
 #   print(i.month)
# Out:
#         Version   Date_of_report Municipality_code Municipality_name  \
# 0             6  4-10-2022 00:30            GM0014         Groningen
# 1             6  4-10-2022 00:30            GM0014         Groningen
# 2             6  4-10-2022 00:30            GM0014         Groningen
# 3             6  4-10-2022 00:30            GM0014         Groningen
# 4             6  4-10-2022 00:30            GM0014         Groningen
# ...         ...              ...               ...               ...
# 327745        6   2-9-2022 00:30            GM0599         Rotterdam
# 327746        6   2-9-2022 00:30            GM0938          Meerssen
# 327747        6   2-9-2022 00:30            GM0599         Rotterdam
# 327748        6   2-9-2022 00:30            GM0599         Rotterdam
# 327749        6   2-9-2022 00:30            GM0114             Emmen
#
#        Security_region_code Security_region_name  \
# 0                      VR01            Groningen
# 1                      VR01            Groningen
# 2                      VR01            Groningen
# 3                      VR01            Groningen
# 4                      VR01            Groningen
# ...                     ...                  ...
# 327745                 VR17   Rotterdam-Rijnmond
# 327746                 VR24         Limburg-Zuid
# 327747                 VR17   Rotterdam-Rijnmond
# 327748                 VR17   Rotterdam-Rijnmond
# 327749                 VR03              Drenthe
#
#         Hospital_admission_notification  Hospital_admission
# 0                                     0                   1
# 1                                     0                   1
# 2                                     0                   1
# 3                                     0                   1
# 4                                     0                   1
# ...                                 ...                 ...
# 327745                               10                   5
# 327746                                2                   1
# 327747                               14                   2
# 327748                                7                   5
# 327749                                5                   1
#
# [327750 rows x 8 columns]

# %%
covid_province = covid.groupby(['Date_of_statistics', 'Security_region_name']).sum()
covid_province.reset_index(inplace=True)
#covid_province['Datetime'] = pd.to_datetime(covid_province['Date_of_publication'])
fig = px.scatter(covid_province, x = 'Date_of_statistics',  y = 'Hospital_admission', color = 'Security_region_name')
fig.update_yaxes(range = [0, 100])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28564\3954259642.py in <module>
# ----> 1 covid_province = covid.groupby(['Date_of_statistics', 'Security_region_name']).sum()
#       2 covid_province.reset_index(inplace=True)
#       3 #covid_province['Datetime'] = pd.to_datetime(covid_province['Date_of_publication'])
#       4 fig = px.scatter(covid_province, x = 'Date_of_statistics',  y = 'Hospital_admission', color = 'Security_region_name')
#       5 fig.update_yaxes(range = [0, 100])
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# --> 897                 dropna=self.dropna,
#     898             )
#     899
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     860                 in_axis, level, gpr = False, gpr, None
#     861             else:
# --> 862                 raise KeyError(gpr)
#     863         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     864             # Add key to exclusions
#
# KeyError: 'Date_of_statistics'
